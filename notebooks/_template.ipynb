# %%
# hack to change jupyter directory in notebooks for imports and handle asyncio
import os
from pathlib import Path
import pandas as pd
from ib_insync import util
if Path.cwd().parts[-1] == 'notebooks':
    root = Path.cwd().parent
    import nest_asyncio
    nest_asyncio.apply()
    util.startLoop()
    pd.options.display.max_columns = None
    pd.options.display.float_format = '{:,.2f}'.format # set float precision with comma
else:
    root = Path.cwd()
os.chdir(root)

# Logger
import logging, logging.config
import yaml

with open(root / 'config' / 'log.yml', 'r') as f:
    log_config = yaml.safe_load(f.read())
    logging.config.dictConfig(log_config)

log = logging.getLogger('ib_log')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\config.py:565, in DictConfigurator.configure(self)
#     564 try:
# --> 565     handler = self.configure_handler(handlers[name])
#     566     handler.name = name
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\config.py:746, in DictConfigurator.configure_handler(self, config)
#     745 try:
# --> 746     result = factory(**kwargs)
#     747 except TypeError as te:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\handlers.py:214, in TimedRotatingFileHandler.__init__(self, filename, when, interval, backupCount, encoding, delay, utc, atTime, errors)
#     213 encoding = io.text_encoding(encoding)
# --> 214 BaseRotatingHandler.__init__(self, filename, 'a', encoding=encoding,
#     215                              delay=delay, errors=errors)
#     216 self.when = when.upper()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\handlers.py:58, in BaseRotatingHandler.__init__(self, filename, mode, encoding, delay, errors)
#      55 """
#      56 Use the specified filename for streamed logging
#      57 """
# ---> 58 logging.FileHandler.__init__(self, filename, mode=mode,
#      59                              encoding=encoding, delay=delay,
#      60                              errors=errors)
#      61 self.mode = mode
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:1169, in FileHandler.__init__(self, filename, mode, encoding, delay, errors)
#    1168 else:
# -> 1169     StreamHandler.__init__(self, self._open())
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\__init__.py:1201, in FileHandler._open(self)
#    1200 open_func = self._builtin_open
# -> 1201 return open_func(self.baseFilename, self.mode,
#    1202                  encoding=self.encoding, errors=self.errors)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:\\Users\\kashi\\python\\logs\\ib.log'
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[1], line 23
#      21 with open(root / 'config' / 'log.yml', 'r') as f:
#      22     log_config = yaml.safe_load(f.read())
# ---> 23     logging.config.dictConfig(log_config)
#      25 log = logging.getLogger('ib_log')
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\config.py:810, in dictConfig(config)
#     808 def dictConfig(config):
#     809     """Configure logging using a dictionary."""
# --> 810     dictConfigClass(config).configure()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\logging\config.py:572, in DictConfigurator.configure(self)
#     570             deferred.append(name)
#     571         else:
# --> 572             raise ValueError('Unable to configure handler '
#     573                              '%r' % name) from e
#     575 # Now do any that were deferred
#     576 for name in deferred:
#
# ValueError: Unable to configure handler 'file'
